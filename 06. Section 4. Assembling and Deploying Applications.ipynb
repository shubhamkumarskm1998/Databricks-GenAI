# %% [markdown]
# ### Assembling and Deploying Applications

# %% [markdown]
# ### Section 4: Assembling and Deploying Applications
# ### System Lifecycle
#   - 1. Business Problem
#   - 2. Define Success Criteria
#   - 3. Data Collection
#   - 4. Data Preprocessing
#   - 5. AI System(RAG/Chain)
#   - 6. Building
#   - 7. Evaluation
#   - 8. Deployment
#   - 9. Monitoring
# ### Phase 1: Development (Static Data)
# - Define business problem
# - Set success criteria
# - Collect and preprocess data
# - Build RAG/AI pipeline
# - Evaluate system performance
# ### Phase 2: Deployment & Production (Dynamic Data)
# - Deploy AI system
# - Monitor performance continuously
# - Handle new/updated data
# ### Key Components
# - Data→Delta Lake
# - Retrieval→Vector Search
# - Orchestration→LangChain
# - LLM→Model Serving(ChatDatabricks)
# - Governance→Unity Catalog
# ### Key Insight
# Development focuses on building accuracy,Production focuses on scalability and monitoring
# ### Exam Tips
# - Lifecycle is iterative(not one-time)
# - Monitoring is critical in production
# - Evaluation happens before deployment
# - RAG pipelines evolve with new data
# ### One-line Summary
# Build→Evaluate→Deploy→Monitor→Improve

# %% [markdown]
# ### Key Points: MLflow PyFunc
# - PyFunc Model→Generic MLflow model interface,deploys models as Python functions
# - Pre-processing→Prepare input data before model (cleaning,normalization,feature extraction)
# - Post-processing→Format and refine model output before serving
# - Implementation→Use mlflow.pyfunc to log,save,load models with pre/post processing
# ### Key Insight
# PyFunc wraps model+pre/post processing into one deployable unit
# ### Exam Tips
# - PyFunc used for custom model deployment
# - Handles real-world input/output pipelines
# - Supports multiple model flavors under one interface
# ### One-line Summary
# PyFunc=Model+Preprocessing+Postprocessing packaged for deployment

# %% [markdown]
# ### 34. Create and Query Vector Search Index
# - Vector Search Setup → Create index from Delta table with embeddings, enable ANN search
# - Query → Use REST API / Python SDK with vector representation for semantic search
# - Features → Auto-sync, self-managed embeddings, CRUD support, integrates with Unity Catalog
#
# ### Key Insight
# Vector Search = Embeddings + ANN search + Realtime Delta Sync
#
# ### 35. Serve LLM using Foundation Model APIs
# - Foundation Models → Access via Databricks Model Serving (APIs for LLMs)
# - Serving Process → Deployment + Query Handling + MLflow Integration + Resource Management
# - Autoscaling → Handles variable load using CPU/GPU efficiently
#
# ### Key Insight
# Model Serving = Scalable API layer for LLMs
#
# ### 36. Resources for RAG Application
# - Compute → Use Databricks CPU/GPU based on load
# - Storage → Delta tables for raw text, embeddings, vector indexes
# - Monitoring → Inference logging for performance and debugging
#
# ### Key Insight
# RAG Infrastructure = Compute + Storage + Monitoring
#
# ### One-line Summary
# Vector Search + Model Serving + Infrastructure = Complete RAG Deployment

# %% [markdown]
# ### Assembling a RAG Application on Databricks
# - LangChain → Orchestration (pipeline + chaining)
# - Mosaic AI Vector Search → Retrieval (semantic search)
# - ChatDatabricks → Response generation (LLM)
#
# ### Key Insight
# RAG Pipeline = Retrieval + Prompt + Generation
#
# ### Pinecone Overview
# - Fully managed vector database for storing, indexing, and searching embeddings
# - Works with text, images, and other unstructured data
# - Used for semantic search, recommendations, similarity matching
#
# ### How Pinecone Works
# - Storing Embeddings → Converts data into vectors and stores them
# - Similarity Search → Finds closest vectors using cosine similarity
# - Real-time & Scalable → Handles millions to billions of vectors with low latency
#
# ### Key Features
# - Fully managed and serverless (no infra management)
# - Scales horizontally for large datasets
# - Fast, low-latency vector search
# - Real-time ingestion and updates
# - Easy integration with ML and data platforms
#
# ### Use Cases
# - RAG for chatbots and assistants
# - Semantic search (meaning over keywords)
# - Recommendation systems (products, content, users)
# - Large-scale similarity matching tasks
#
# ### Key Insight
# Pinecone = Managed Vector DB for scalable semantic search
#
# ### One-line Summary
# Databricks RAG = LangChain + Vector Search + LLM (ChatDatabricks/Pinecone)
